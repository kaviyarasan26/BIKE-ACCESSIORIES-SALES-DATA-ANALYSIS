# %% [markdown]
# ## To read the data frame using pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("Fezzari Sales.csv")

# %%
df
# Out:
#              Date   Time    Year  Customer Age Customer Gender        Country  \
# 0        02-19-16  13:08  2016.0          29.0               F  United States
# 1         2-20-16  10:29  2016.0          29.0               F  United States
# 2         2-27-16  13:23  2016.0          29.0               F  United States
# 3      12-03-2016  20:33  2016.0          29.0               F  United States
# 4      12-03-2016  10:37  2016.0          29.0               F  United States
# ...           ...    ...     ...           ...             ...            ...
# 34862  07-02-2016  11:55  2016.0          38.0               M         France
# 34863     3-13-15  11:42  2015.0          38.0               M         France
# 34864  05-04-2015  14:30  2015.0          38.0               M         France
# 34865     8-30-15  15:11  2015.0          38.0               M         France
# 34866         NaN    NaN     NaN           NaN             NaN            NaN
#
# ...

# %% [markdown]
# ## To check null values

# %%
df.isnull()
# Out:
#         Date   Time   Year  Customer Age  Customer Gender  Country  State  \
# 0      False  False  False         False            False    False  False
# 1      False  False  False         False            False    False  False
# 2      False  False  False         False            False    False  False
# 3      False  False  False         False            False    False  False
# 4      False  False  False         False            False    False  False
# ...      ...    ...    ...           ...              ...      ...    ...
# 34862  False  False  False         False            False    False  False
# 34863  False  False  False         False            False    False  False
# 34864  False  False  False         False            False    False  False
# 34865  False  False  False         False            False    False  False
# 34866   True   True   True          True             True     True   True
#
#        Product Category  Sub Category  Quantity  Unit Cost  Revenue  Payment  \
# ...

# %% [markdown]
# ## To find null value counts

# %%
df.isnull().sum()
# Out:
# Date                1
# Time                1
# Year                1
# Customer Age        3
# Customer Gender     3
# Country             1
# State               3
# Product Category    4
# Sub Category        3
# Quantity            1
# Unit Cost           3
# Revenue             1
# Payment             0
# Rating              1
# dtype: int64

# %% [markdown]
# ## Finding the null values

# %%
new_df = df[df.isna().any(axis=1)]
new_df
# Out:
#              Date   Time    Year  Customer Age Customer Gender        Country  \
# 19        9-24-15  15:30  2015.0          29.0               F  United States
# 21     07-10-2015  10:40  2015.0           NaN               F  United States
# 58        3-21-16  15:55  2016.0          19.0               M  United States
# 63        8-21-15  12:27  2015.0          19.0               M  United States
# 66        1-25-16  15:43  2016.0          19.0               F  United States
# 77        8-14-15  15:48  2015.0          24.0               F  United States
# 110    08-08-2015  11:32  2015.0          19.0               F  United States
# 140       8-25-15  13:00  2015.0           NaN               M  United States
# 144       4-16-16  16:37  2016.0          25.0               F  United States
# 151    07-02-2016  16:07  2016.0          53.0             NaN  United States
# 164    11-04-2016  15:24  2016.0          53.0             NaN  United States
# ...

# %% [markdown]
# ## To clean the null values

# %%
df=df.dropna(axis=0,how='any')
df
# Out:
#              Date   Time    Year  Customer Age Customer Gender        Country  \
# 0        02-19-16  13:08  2016.0          29.0               F  United States
# 1         2-20-16  10:29  2016.0          29.0               F  United States
# 2         2-27-16  13:23  2016.0          29.0               F  United States
# 3      12-03-2016  20:33  2016.0          29.0               F  United States
# 4      12-03-2016  10:37  2016.0          29.0               F  United States
# ...           ...    ...     ...           ...             ...            ...
# 34860     2-24-16  13:24  2016.0          37.0               M        Germany
# 34861     3-22-15  18:06  2015.0          38.0               M         France
# 34863     3-13-15  11:42  2015.0          38.0               M         France
# 34864  05-04-2015  14:30  2015.0          38.0               M         France
# 34865     8-30-15  15:11  2015.0          38.0               M         France
#
# ...

# %% [markdown]
# ## After we clean the all null values

# %%
df.isna().sum()
# Out:
# Date                0
# Time                0
# Year                0
# Customer Age        0
# Customer Gender     0
# Country             0
# State               0
# Product Category    0
# Sub Category        0
# Quantity            0
# Unit Cost           0
# Revenue             0
# Payment             0
# Rating              0
# dtype: int64

# %% [markdown]
# ## To getting the data type

# %%
df.dtypes
# Out:
# Date                 object
# Time                 object
# Year                float64
# Customer Age        float64
# Customer Gender      object
# Country              object
# State                object
# Product Category     object
# Sub Category         object
# Quantity            float64
# Unit Cost           float64
# Revenue             float64
# Payment              object
# Rating              float64
# dtype: object

# %% [markdown]
# ## TO typecasting the datatypes

# %%
df['Customer Age']=df['Customer Age'].astype('int')
df['Year']=df['Year'].astype('int')
df['Quantity']=df['Quantity'].astype('int')
df.dtypes
# Out:
# C:\Users\Kaviy\AppData\Local\Temp\ipykernel_4612\2194745638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Customer Age']=df['Customer Age'].astype('int')
# C:\Users\Kaviy\AppData\Local\Temp\ipykernel_4612\2194745638.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=df['Year'].astype('int')
# C:\Users\Kaviy\AppData\Local\Temp\ipykernel_4612\2194745638.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## To count the datatypes

# %%
df.dtypes.value_counts()
# Out:
# object     8
# int32      3
# float64    3
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Year  Customer Age      Quantity     Unit Cost       Revenue  \
# count  34853.000000  34853.000000  34853.000000  34853.000000  34853.000000
# mean    2015.569277     36.384902      2.002496    349.886978    640.863340
# std        0.495185     11.111604      0.813929    490.055370    736.644793
# min     2015.000000     17.000000      1.000000      0.670000      2.000000
# 25%     2015.000000     28.000000      1.000000     45.000000    102.000000
# 50%     2016.000000     35.000000      2.000000    150.000000    319.000000
# 75%     2016.000000     44.000000      3.000000    455.000000    902.000000
# max     2016.000000     87.000000      3.000000   3240.000000   5082.000000
#
#              Rating
# count  34853.000000
# mean       7.491177
# std        1.578697
# min        5.000000
# 25%        6.000000
# 50%        7.500000
# 75%        9.000000
# max       10.000000

# %% [markdown]
# ## Creating Additional column for month

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month
# Out:
# C:\Users\Kaviy\AppData\Local\Temp\ipykernel_4612\1163112680.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Month'] = pd.to_datetime(df['Date']).dt.month
# C:\Users\Kaviy\AppData\Local\Temp\ipykernel_4612\1163112680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df
# Out:
#              Date   Time  Year  Customer Age Customer Gender        Country  \
# 0        02-19-16  13:08  2016            29               F  United States
# 1         2-20-16  10:29  2016            29               F  United States
# 2         2-27-16  13:23  2016            29               F  United States
# 3      12-03-2016  20:33  2016            29               F  United States
# 4      12-03-2016  10:37  2016            29               F  United States
# ...           ...    ...   ...           ...             ...            ...
# 34860     2-24-16  13:24  2016            37               M        Germany
# 34861     3-22-15  18:06  2015            38               M         France
# 34863     3-13-15  11:42  2015            38               M         France
# 34864  05-04-2015  14:30  2015            38               M         France
# 34865     8-30-15  15:11  2015            38               M         France
#
# ...

# %% [markdown]
# ## To find Which one is the best month for sales? How much was earned this month?

# %%
df['Sales Cost'] = df['Quantity']* df['Unit Cost']
df
# Out:
# C:\Users\Kaviy\AppData\Local\Temp\ipykernel_4612\701021180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales Cost'] = df['Quantity']* df['Unit Cost']
#              Date   Time  Year  Customer Age Customer Gender        Country  \
# 0        02-19-16  13:08  2016            29               F  United States
# 1         2-20-16  10:29  2016            29               F  United States
# 2         2-27-16  13:23  2016            29               F  United States
# 3      12-03-2016  20:33  2016            29               F  United States
# 4      12-03-2016  10:37  2016            29               F  United States
# ...           ...    ...   ...           ...             ...            ...
# ...

# %% [markdown]
# ## Grouping Month by Sales Cost

# %%
df_temp = df.groupby('Month').sum()['Sales Cost'].reset_index()
df_temp
# Out:
#     Month  Sales Cost
# 0       1  1734134.19
# 1       2  1612798.61
# 2       3  1735518.24
# 3       4  1779628.02
# 4       5  2014706.84
# 5       6  2130992.54
# 6       7  1431118.20
# 7       8  1430123.61
# 8       9  1409997.43
# 9      10  1385913.93
# 10     11  1525403.64
# 11     12  1883753.77

# %% [markdown]
# ## Plotting Sales by Month

# %%
import matplotlib.pyplot as plt

months = range(1,13)
print(months)

plt.bar(months,df.groupby(['Month']).sum()['Sales Cost'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# range(1, 13)

# %% [markdown]
# # inference:
#
# ## Here in Month of 6 has high Sales.So June is the best month for sales with 2 USD to 3 USD

# %% [markdown]
# # Which Country is more profitable

# %% [markdown]
# # Grouping the Country by Revenue

# %%
new_df=df.groupby(['Country']).sum()
new_df.loc[:,'Revenue']
# Out:
# Country
# France             3444133.0
# Germany            4244510.0
# United Kingdom     4276220.0
# United States     10371147.0
# Name: Revenue, dtype: float64

# %% [markdown]
# # Finding the product category and subcategory which are the more profitable
# # Sorting Product Category and Subcategory based on revenue

# %%
cat_subcat = pd.DataFrame(df.groupby(['Product Category', 'Sub Category']).sum()['Revenue'])
cat_subcat.sort_values(['Product Category','Revenue'], ascending=False)
# Out:
#                                       Revenue
# Product Category Sub Category
# Clothing         Jerseys            1831986.0
#                  Shorts              689184.0
#                  Vests               368681.0
#                  Caps                255992.0
#                  Gloves              228353.0
#                  Socks                60972.0
# Bikes            Mountain Bikes     5172439.0
#                  Road Bikes         3921989.0
#                  Touring Bikes      2387910.0
# Accessories      Tires and Tubes    2865498.0
#                  Helmets            2738055.0
#                  Bottles and Cages   709407.0
#                  Hydration Packs     403276.0
#                  Fenders             329204.0
#                  Bike Stands         149323.0
#                  Bike Racks          140854.0
#                  Cleaners             82887.0

# %% [markdown]
# # Inference:
#
# ## i)In Clothing,jerseys are more profitable
# ## ii)In Bikes,Mountain Bikes are more profitable
# ## iii)In Accessories Tires and Tubes are more profitable

# %% [markdown]
# # What are the top 10 product by Sales
# ## Sorting top 10 Products by Sales Cost

# %%
product_sales = pd.DataFrame(df.groupby('Sub Category').sum()['Sales Cost'])
product_sales.sort_values(by=['Sales Cost'], inplace=True, ascending=False)
product_sales.head(10)
# Out:
#                    Sales Cost
# Sub Category
# Mountain Bikes     5027183.58
# Road Bikes         3823818.35
# Tires and Tubes    2353428.93
# Touring Bikes      2293103.10
# Helmets            2219595.58
# Jerseys            1531295.87
# Shorts              602139.99
# Bottles and Cages   579840.55
# Hydration Packs     330935.06
# Vests               310337.04

# %% [markdown]
# # Which is the most sold product?
# ## Grouping and Sorting products based on Quantity

# %%
most_selling_products = pd.DataFrame(df.groupby('Sub Category').sum()['Quantity'])
most_selling_products.sort_values(by=['Quantity'], inplace=True, ascending=False)
most_selling_products[:10]
# Out:
#                    Quantity
# Sub Category
# Tires and Tubes       22201
# Bottles and Cages     10558
# Helmets                8384
# Road Bikes             6119
# Mountain Bikes         5494
# Jerseys                4030
# Caps                   3020
# Touring Bikes          2673
# Fenders                1494
# Shorts                 1129

# %% [markdown]
# # Plotting most sold products based on Quantity

# %%
product_group = df.groupby('Sub Category')
quantity = product_group.sum()['Quantity']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity)
plt.xticks(keys, rotation='vertical', size=8)
plt.ylabel('Quantity')
plt.xlabel('Sub Category')
plt.show()

# %% [markdown]
# ## Inference:
# ## maximum of the customer bought tires and tubes, the quantity upto 22,000

# %%
category_chart=df['Sub Category'].value_counts()
category_chart.plot(kind = 'pie', autopct='%1.1f%%', figsize=(9, 15)).legend()

# %% [markdown]
# ## Inference:
# ## value calculate with matplot in 31.9% of coustomer bought tires and tubes

# %% [markdown]
# # To find What is the most preferred Payment Method
# ## Counting Payment method

# %%
df['Payment'].value_counts()  # finding the payment method count
# Out:
# Payment
# Cash           16699
# Credit Card    11688
# Ewallet         6466
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Payment', data=df)
plt.show()

# %% [markdown]
# ## 1.most of the customers using cash payment hiked upto count of 16000
# ## 2.customers using credit card are in the range from 11500 to 12000
# ## 3.least amount of customer using ewallet upto 6000
# ### From this we can know that people are using cash payment which are more convienient

# %% [markdown]
# # Grouping the customer age and quantity

# %%
Age=df.groupby('Customer Age').sum()['Quantity']
Age=Age[Age == Age.max()]
Age
# Out:
# Customer Age
# 31    2630
# Name: Quantity, dtype: int32

# %%
import seaborn as sns
plt.figure(figsize=(20, 10))
sns.countplot(x='Customer Age', data=df)
plt.show()

# %% [markdown]
# ## Inference :
# ## The age category of 31 have done more purchase when compare to other age categories.

# %%
sns.displot( df, x="Customer Age", col="Payment", row="Customer Gender",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Inference :
# ## 1.comparatively female using hand cash more than male
# ## 2.women use hand cash count upto 900
# ## 3.male use hand cash count nearly 900
# --
#
# ## 1.comparativly male using credit card more than female
# ## 2.male using credit card count is 650
# ## 3.female using count is nearly 610
# --
# ## 1.least amount of customers using ewallet
# ## 2.using count of female is nearly 300
# ## 3.and the male count is upto 350

# %% [markdown]
# # One sample T-test

# %%
# from scipy.stats import ttest_1samp
from scipy.stats import ttest_1samp

hm = 36.40  # HYPOTHESISED MEAN 
t_stat, p_value = ttest_1samp(df['Customer Age'],hm)
alpha = 0.05 # acceptance error percent
print(f"T-statistic:{t_stat}")
print(f"P-value:{p_value}")
if p_value<alpha:
    print(f"Reject null hypothesis at alpha ={alpha}")
else:
    print(f"Failed to reject null hypothesis at alpha = {alpha}")
# Out:
# T-statistic:-0.25366118574988133
# P-value:0.7997588189996673
# Failed to reject null hypothesis at alpha = 0.05

# %% [markdown]
# # Given hypothysis Mean is 36.40 for group of AGE with significance level of error is 5 % allowed
# # In this OneSample T-test We can confidently tell 95% the given mean value is FAILD TO REJECT NULL HYPOTHISIS because of  the p_value is less than significant level

# %%
df.to_csv('Fezzari_sales1.csv')
